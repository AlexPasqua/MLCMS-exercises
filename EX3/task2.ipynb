# %% [markdown]
# # Task 2

# %%
from utilities import create_bifurcation_diagram_1D

# %% [markdown]
# **Task2.1**
#
# Create the bifurcation diagram for function:
#
# $$\dot x = \alpha - x^2$$

# %%
# producing the bifurcation diagram for alpha in [-1,1]
create_bifurcation_diagram_1D('alpha - x**2', min_alpha=-1, max_alpha=1.1, alpha_step=0.1)
# Out:
# -1.0 [-1.0*I, 1.0*I]
# -0.9 [-0.948683298050514*I, 0.948683298050514*I]
# -0.8 [-0.894427190999916*I, 0.894427190999916*I]
# -0.7 [-0.836660026534076*I, 0.836660026534076*I]
# -0.6 [-0.774596669241483*I, 0.774596669241483*I]
# -0.5 [-0.707106781186548*I, 0.707106781186548*I]
# -0.4 [-0.632455532033676*I, 0.632455532033676*I]
# -0.3 [-0.547722557505166*I, 0.547722557505166*I]
# -0.2 [-0.447213595499958*I, 0.447213595499958*I]
# -0.1 [-0.316227766016838*I, 0.316227766016838*I]
# -0.0 [0]
# 0.1 [-0.316227766016838, 0.316227766016838]
# 0.2 [-0.447213595499958, 0.447213595499958]
# 0.3 [-0.547722557505166, 0.547722557505166]
# 0.4 [-0.632455532033676, 0.632455532033676]
# 0.5 [-0.707106781186548, 0.707106781186548]
# 0.6 [-0.774596669241483, 0.774596669241483]
# 0.7 [-0.836660026534076, 0.836660026534076]
# 0.8 [-0.894427190999916, 0.894427190999916]
# 0.9 [-0.948683298050514, 0.948683298050514]
# 1.0 [-1.00000000000000, 1.00000000000000]

# %% [markdown]
# **Task2.2**
#
# Create the bifurcation diagram for function:
#
# $$\dot x = \alpha - 2x^2 - 3$$

# %%
# producing the bifurcation diagram for alpha in [-1,1]
create_bifurcation_diagram_1D('alpha - 2*(x**2) - 3.', min_alpha=-10, max_alpha=10.1, alpha_step=0.1)
# Out:
# -10.0 [-2.54950975679639*I, 2.54950975679639*I]
# -9.9 [-2.53968501984006*I, 2.53968501984006*I]
# -9.8 [-2.5298221281347*I, 2.5298221281347*I]
# -9.7 [-2.51992063367083*I, 2.51992063367083*I]
# -9.6 [-2.50998007960223*I, 2.50998007960223*I]
# -9.5 [-2.5*I, 2.5*I]
# -9.4 [-2.48997991959775*I, 2.48997991959775*I]
# -9.3 [-2.47991935352745*I, 2.47991935352745*I]
# -9.2 [-2.46981780704569*I, 2.46981780704569*I]
# -9.1 [-2.45967477524977*I, 2.45967477524977*I]
# -9.0 [-2.44948974278318*I, 2.44948974278318*I]
# -8.9 [-2.43926218353009*I, 2.43926218353009*I]
# -8.8 [-2.42899156029822*I, 2.42899156029822*I]
# -8.7 [-2.41867732448956*I, 2.41867732448956*I]
# -8.6 [-2.40831891575846*I, 2.40831891575846*I]
# -8.5 [-2.39791576165636*I, 2.39791576165636*I]
# -8.4 [-2.38746727726266*I, 2.38746727726266*I]
# -8.3 [-2.37697286480094*I, 2.37697286480094*I]
# -8.2 [-2.36643191323985*I, 2.36643191323985*I]
# -8.1 [-2.35584379787795*I, 2.35584379787795*I]
# ...
