# %% [markdown]
# # Task 4

# %%
from utilities import plot_logistic_map_bifurcations, logistic_map_cobweb_plot, lorenz_traj

# %% [markdown]
# ### Task4.1:
#
# System: $x_{n+1}=rx_n(1-x_n)$
#
# 1. Vary $r$ from 0 to 2. Which bifurcations occur?
# At which numerical values do you find steady states of the system?

# %%
plot_logistic_map_bifurcations(min_r=0, max_r=2)
logistic_map_cobweb_plot(r=0.8, x0=.1, n=100)

# %% [markdown]
# ### Task 4.2:
# Now vary $r$ from 2 to 4.

# %%
plot_logistic_map_bifurcations(min_r=2, max_r=4)
logistic_map_cobweb_plot(r=2.5, x0=.1, n=100)
logistic_map_cobweb_plot(r=3.25, x0=.1, n=100)
logistic_map_cobweb_plot(r=3.8, x0=.1, n=100)

# %% [markdown]
# ### Task 4.3:
# Plot a bifurcation diagram for r between 0 and 4 (horizontal axis),
# x between 0 and 1 (vertical axis).

# %%
plot_logistic_map_bifurcations(min_r=0, max_r=4)

# %% [markdown]
# **Steady states:**
# - $\forall r \in (0,\ 1]:\ x = 0$ is a steady state
# - $\forall r \in (1,\ 3)$ there is 1 steady state
# - $\forall r \geq 3$ there are multiple steady states.
# Their number tend to increase (doubling) as $r$ increases,
# with some exceptions where the steady states become 3 again.
#
# **Limit cycles:**
# [FILL HERE] eh da quel plot non si vedono, come facciamo?

# %% [markdown]
# ## Part 2
# Show a trajectory of the Lorenz attractor starting at $x_0 = (10; 10; 10)$

# %%
lorenz_traj(start_x=(10, 10, 10), s=10, b=2.667, r=28)
